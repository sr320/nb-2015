# %%
# !/Applications/bioinfo/BSMAP/bsmap-2.74/bsmap \
-a /Users/sr320/data-genomic/tentacle/20150521_trimmed_2212_lane2_400ppm_GCCAAT.fastq.gz \
-d /Users/sr320/data-genomic/tentacle/Crassostrea_gigas.GCA_000297895.1.26.dna_sm.genome.fa \
-o /Users/sr320/data-genomic/tentacle/400-GCA_000297895.1.26.dna.genome-sm.sam \
-n 1 \
-p 6 \
-v 7 \
# Out:
# BSMAP v2.74
# Start at:  Mon Jun  1 09:37:10 2015
#
# Input reference file: /Users/sr320/data-genomic/tentacle/Crassostrea_gigas.GCA_000297895.1.26.dna_sm.genome.fa 	(format: FASTA)
# Load in 7658 db seqs, total size 557717710 bp. 6 secs passed
# total_kmers: 43046721
# Create seed table. 20 secs passed
# max number of mismatches: 7	max gap size: 0
# kmer cut-off ratio: 5e-07
# max multi-hits: 100	max Ns: 5	seed size: 16	index interval: 4
# quality cutoff: 0	base quality char: '!'
# min fragment size:28	max fragemt size:500
# start from read #1	end at read #4294967295
# additional alignment: T in reads => C in reference
# mapping strand: ++,-+,+-,--
# Single-end alignment(6 threads)
# Input read file: /Users/sr320/data-genomic/tentacle/20150521_trimmed_2212_lane2_400ppm_GCCAAT.fastq.gz 	(format: gzipped FASTQ)
# Output file: /Users/sr320/data-genomic/tentacle/400-GCA_000297895.1.26.dna.genome-sm.sam	 (format: SAM)
# Thread #2: 	100000 reads finished. 52 secs passed
# ...

# %%
# !/Applications/bioinfo/BSMAP/bsmap-2.74/bsmap \
-a /Users/sr320/data-genomic/tentacle/20150521_trimmed_2212_lane2_1000ppm_CTTGTA.fastq.gz \
-d /Users/sr320/data-genomic/tentacle/Crassostrea_gigas.GCA_000297895.1.26.dna_sm.genome.fa \
-o /Users/sr320/data-genomic/tentacle/1000-GCA_000297895.1.26.dna.genome-sm.sam \
-n 1 \
-p 6 \
-v 7 \
# Out:
# BSMAP v2.74
# Start at:  Tue Jun  2 09:08:59 2015
#
# Input reference file: /Users/sr320/data-genomic/tentacle/Crassostrea_gigas.GCA_000297895.1.26.dna_sm.genome.fa 	(format: FASTA)
# Load in 7658 db seqs, total size 557717710 bp. 6 secs passed
# total_kmers: 43046721
# Create seed table. 21 secs passed
# max number of mismatches: 7	max gap size: 0
# kmer cut-off ratio: 5e-07
# max multi-hits: 100	max Ns: 5	seed size: 16	index interval: 4
# quality cutoff: 0	base quality char: '!'
# min fragment size:28	max fragemt size:500
# start from read #1	end at read #4294967295
# additional alignment: T in reads => C in reference
# mapping strand: ++,-+,+-,--
# Single-end alignment(6 threads)
# Input read file: /Users/sr320/data-genomic/tentacle/20150521_trimmed_2212_lane2_1000ppm_CTTGTA.fastq.gz 	(format: gzipped FASTQ)
# Output file: /Users/sr320/data-genomic/tentacle/1000-GCA_000297895.1.26.dna.genome-sm.sam	 (format: SAM)
# Thread #3: 	200000 reads finished. 49 secs passed
# ...

# %%
# !python /Applications/bioinfo/BSMAP/bsmap-2.74/methratio.py \
-d /Users/sr320/data-genomic/tentacle/Crassostrea_gigas.GCA_000297895.1.26.dna_sm.genome.fa \
-u -z -g \
-o /Users/sr320/data-genomic/tentacle/methratio_out_OA400.txt \
-s /Applications/bioinfo/BSMAP/bsmap-2.74/samtools \
/Users/sr320/data-genomic/tentacle/400-GCA_000297895.1.26.dna.genome-sm.sam
# Out:
# @ Tue Jun  2 09:01:12 2015: reading reference /Users/sr320/data-genomic/tentacle/Crassostrea_gigas.GCA_000297895.1.26.dna_sm.genome.fa ...
# @ Tue Jun  2 09:01:34 2015: reading /Users/sr320/data-genomic/tentacle/400-GCA_000297895.1.26.dna.genome-sm.sam ...
# [samopen] SAM header is present: 7658 sequences.
# @ Tue Jun  2 09:01:55 2015: combining CpG methylation from both strands ...
# @ Tue Jun  2 09:02:17 2015: writing /Users/sr320/data-genomic/tentacle/methratio_out_OA400.txt ...
# @ Tue Jun  2 09:03:11 2015: done.
# total 59695 valid mappings, 19866 covered cytosines, average coverage: 6.11 fold.

# %%
# !python /Applications/bioinfo/BSMAP/bsmap-2.74/methratio.py \
-d /Users/sr320/data-genomic/tentacle/Crassostrea_gigas.GCA_000297895.1.26.dna_sm.genome.fa \
-u -z -g \
-o /Users/sr320/data-genomic/tentacle/methratio_out_OA1000.txt \
-s /Applications/bioinfo/BSMAP/bsmap-2.74/samtools \
/Users/sr320/data-genomic/tentacle/1000-GCA_000297895.1.26.dna.genome-sm.sam
# Out:
# @ Tue Jun  2 10:44:04 2015: reading reference /Users/sr320/data-genomic/tentacle/Crassostrea_gigas.GCA_000297895.1.26.dna_sm.genome.fa ...
# @ Tue Jun  2 10:44:26 2015: reading /Users/sr320/data-genomic/tentacle/1000-GCA_000297895.1.26.dna.genome-sm.sam ...
# [samopen] SAM header is present: 7658 sequences.
# @ Tue Jun  2 10:44:46 2015: combining CpG methylation from both strands ...
# @ Tue Jun  2 10:45:05 2015: writing /Users/sr320/data-genomic/tentacle/methratio_out_OA1000.txt ...
# @ Tue Jun  2 10:45:59 2015: done.
# total 57991 valid mappings, 11362 covered cytosines, average coverage: 11.58 fold.

# %%
# !wc /Users/sr320/data-genomic/tentacle/methratio_out_OA400.txt
# !head /Users/sr320/data-genomic/tentacle/methratio_out_OA400.txt
# Out:
#    19867  238397  972127 /Users/sr320/data-genomic/tentacle/methratio_out_OA400.txt
# chr	pos	strand	context	ratio	eff_CT_count	C_count	CT_count	rev_G_count	rev_GA_count	CI_lower	CI_upper
# C12706	44	-	TTGAC	0.000	1.00	0	1	0	0	0.000	0.793
# C12706	48	-	CAGCA	0.000	1.00	0	1	0	0	0.000	0.793
# C12706	51	-	CAGAG	0.000	1.00	0	1	0	0	0.000	0.793
# C12706	53	-	GAGAG	0.000	1.00	0	1	0	0	0.000	0.793
# C12706	55	-	GAGGG	0.000	1.00	0	1	0	0	0.000	0.793
# C12706	71	+	CGCGT	0.000	1.00	0	1	1	1	0.000	0.793
# C12706	78	-	TTGAA	0.000	2.00	0	2	0	0	0.000	0.658
# C12706	85	+	TCCAC	0.000	1.00	0	1	2	2	0.000	0.793
# C12706	88	+	ACCAT	0.000	1.00	0	1	0	0	0.000	0.793

# %%
# !grep "[A-Z][A-Z]CG[A-Z]" \
</Users/sr320/data-genomic/tentacle/methratio_out_OA400.txt> \
/Users/sr320/data-genomic/tentacle/methratio_out_OA400_CG.txt
# !awk -f /Users/sr320/git-repos/nb-2015/util/script-box/mr3x.awk \
/Users/sr320/data-genomic/tentacle/methratio_out_OA400_CG.txt \
> /Users/sr320/data-genomic/tentacle/3x_methratio_out_OA400_CG.txt
# !awk -f /Users/sr320/git-repos/nb-2015/util/script-box/mr_gg.awk.sh \
/Users/sr320/data-genomic/tentacle/3x_methratio_out_OA400_CG.txt \
> /Users/sr320/data-genomic/tentacle/mkfmt_3x_methratio_out_OA400_CG.txt

# %%
# !wc /Users/sr320/data-genomic/tentacle/3x_methratio_out_OA400_CG.txt
# Out:
#      697    8364   34148 /Users/sr320/data-genomic/tentacle/3x_methratio_out_OA400_CG.txt
