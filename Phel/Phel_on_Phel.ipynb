# %%
# !head /Volumes/caviar/Dropbox/Steven/eimd/data/blast_db/Phel_transcriptome_clc_v3.fasta
# Out:
# >Phel_clc_contig_1
# ...
# >Phel_clc_contig_10
# ...
# >Phel_clc_contig_100
# ...
# >Phel_clc_contig_1000
# ...
# >Phel_clc_contig_10000
# ...

# %%
# !wc -l /Volumes/caviar/Dropbox/Steven/eimd/data/blast_db/Phel_transcriptome_clc_v3.fasta
# Out:
#    58952 /Volumes/caviar/Dropbox/Steven/eimd/data/blast_db/Phel_transcriptome_clc_v3.fasta

# %%
# !fgrep -c ">" /Volumes/caviar/Dropbox/Steven/eimd/data/blast_db/Phel_transcriptome_clc_v3.fasta
# Out:
# 29476

# %%
# !blastn \
-query /Volumes/caviar/Dropbox/Steven/eimd/data/blast_db/Phel_transcriptome_clc_v3.fasta \
-db /Volumes/caviar/Dropbox/Steven/eimd/data/blast_db/Phel_transcriptome_clc_v3 \
-out /Volumes/caviar/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_a \
-evalue 1E-40 \
-outfmt 6 \
-num_threads 2

# %%
# !head -50 /Volumes/caviar/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_a
# Out:
# Phel_clc_contig_1	Phel_clc_contig_1	100.00	905	0	0	1	905	1	905	0.0	1672
# Phel_clc_contig_10	Phel_clc_contig_10	100.00	2138	0	0	1	2138	1	2138	0.0	3949
# Phel_clc_contig_10	Phel_clc_contig_11646	94.41	143	7	1	5	146	514	372	1e-55	 219
# Phel_clc_contig_10	Phel_clc_contig_16021	93.71	143	9	0	3	145	753	611	1e-54	 215
# Phel_clc_contig_10	Phel_clc_contig_6154	92.36	144	10	1	3	146	2688	2546	3e-51	 204
# Phel_clc_contig_10	Phel_clc_contig_11721	93.80	129	8	0	21	149	1303	1175	2e-48	 195
# Phel_clc_contig_10	Phel_clc_contig_3551	91.30	138	12	0	9	146	3753	3616	8e-47	 189
# Phel_clc_contig_10	Phel_clc_contig_11647	93.65	126	8	0	21	146	4	129	8e-47	 189
# Phel_clc_contig_10	Phel_clc_contig_3783	90.21	143	13	1	4	146	2517	2376	1e-45	 185
# Phel_clc_contig_10	Phel_clc_contig_11648	89.86	138	14	0	5	142	1	138	2e-43	 178
# Phel_clc_contig_100	Phel_clc_contig_100	100.00	8078	0	0	1	8078	1	8078	0.0	1.492e+04
# Phel_clc_contig_100	Phel_clc_contig_100	100.00	2225	0	0	8120	10344	8120	10344	0.0	4109
# ...

# %%
# !wc -l /Volumes/caviar/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_a
# Out:
#   216305 /Volumes/caviar/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_a

# %%
# !blastn -help
# Out:
# USAGE
#   blastn [-h] [-help] [-import_search_strategy filename]
#     [-export_search_strategy filename] [-task task_name] [-db database_name]
#     [-dbsize num_letters] [-gilist filename] [-seqidlist filename]
#     [-negative_gilist filename] [-entrez_query entrez_query]
#     [-db_soft_mask filtering_algorithm] [-db_hard_mask filtering_algorithm]
#     [-subject subject_input_file] [-subject_loc range] [-query input_file]
#     [-out output_file] [-evalue evalue] [-word_size int_value]
#     [-gapopen open_penalty] [-gapextend extend_penalty]
#     [-perc_identity float_value] [-xdrop_ungap float_value]
#     [-xdrop_gap float_value] [-xdrop_gap_final float_value]
#     [-searchsp int_value] [-max_hsps_per_subject int_value] [-penalty penalty]
#     [-reward reward] [-no_greedy] [-min_raw_gapped_score int_value]
#     [-template_type type] [-template_length int_value] [-dust DUST_options]
#     [-filtering_db filtering_database]
#     [-window_masker_taxid window_masker_taxid]
# ...

# %%
# !blastn \
-query /Volumes/caviar/Dropbox/Steven/eimd/data/blast_db/Phel_transcriptome_clc_v3.fasta \
-db /Volumes/caviar/Dropbox/Steven/eimd/data/blast_db/Phel_transcriptome_clc_v3 \
-out /Volumes/caviar/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_b \
-evalue 1E-80 \
-word_size 64 \
-outfmt 6 \
-max_hsps_per_subject 1 \
-num_threads 2
# !wc -l /Volumes/caviar/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_b
# !head /Volumes/caviar/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_b
# Out:
#    35006 /Volumes/caviar/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_b
# Phel_clc_contig_1	Phel_clc_contig_1	100.00	905	0	0	1	905	1	905	0.0	1672
# Phel_clc_contig_10	Phel_clc_contig_10	100.00	2138	0	0	1	2138	1	2138	0.0	3949
# Phel_clc_contig_100	Phel_clc_contig_100	100.00	8078	0	0	1	8078	1	8078	0.0	1.492e+04
# Phel_clc_contig_100	Phel_clc_contig_100	100.00	2225	0	0	8120	10344	8120	10344	0.0	4109
# Phel_clc_contig_1000	Phel_clc_contig_1000	100.00	3651	0	0	1	3651	1	3651	0.0	6743
# Phel_clc_contig_1000	Phel_clc_contig_1000	100.00	980	0	0	3697	4676	3697	4676	0.0	1799
# Phel_clc_contig_10000	Phel_clc_contig_10000	100.00	843	0	0	1	843	1	843	0.0	1557
# Phel_clc_contig_10001	Phel_clc_contig_10001	100.00	1108	0	0	1	1108	1	1108	0.0	2047
# Phel_clc_contig_10002	Phel_clc_contig_10002	100.00	3127	0	0	1	3127	1	3127	0.0	5775
# Phel_clc_contig_10003	Phel_clc_contig_10003	100.00	1120	0	0	1	1120	1	1120	0.0	2069

# %%
# !awk '$2 == $1 { print $0 }' /Volumes/caviar/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_b | wc -l
# Out:
#    32841

# %%
# !awk '$2 != $1 { print $0 }' /Users/sr320/Dropbox/Steven/eimd/data/blast_output/Phel3_Phel3_b | wc -l
# Out:
#     2165
