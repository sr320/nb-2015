# %%
import pandas as pd

# %%
# !head /Users/sr320/Desktop/badge.csv
# Out:
# Timestamp,Publication/preprint has complementing code & data repositories that can be used to reproduce results,"Code repositories have detailed, plain-English README files describing the computational environment and dependencies (including version numbers) to facilitate independent reproduction","Computational environment captured (ie. in a virtual machine image/dockerfile/vagrantfile, etc.) in one or more research compendia ",Primary software tools for research are open source ,Submit your code for review,Perform code review for someone else,Have the substantive results of your publication reproduced by someone else using your code and data,Perform a reproducibility review for someone else,Analysis/scripts/code developed in one or more GitHub/BitBucket/GitLab or similar version-controlled open code repository,Code has one or more tests,One or more code repository has an open license (eg. MIT/BSD/GPL2 etc.),One or more code repository has a persistent URL (eg. DOI) to a specific re
# ...

# %%
bres=pd.read_csv("/Users/sr320/Desktop/badge.csv")

# %%
bres
# Out:
#            Timestamp  \
# 0  6/4/2015 17:18:32
# 1  6/4/2015 17:44:10
# 2  6/4/2015 11:32:21
#
#   Publication/preprint has complementing code & data repositories that can be used to reproduce results  \
# 0       10.7287/peerj.preprints.704\n10.1101/012831
# 1  10.1016/j.jhevol.2015.03.014, \n10.1002/arco.5...
# 2                http://dx.doi.org/10.1063/1.1791051
#
#   Code repositories have detailed, plain-English README files describing the computational environment and dependencies (including version numbers) to facilitate independent reproduction  \
# 0  https://github.com/jheare/OluridaSurvey2014\nh...
# 1  https://github.com/benmarwick/1989-excavation-...
# 2  https://github.com/m-a-d-n-e-s-s/madness/blob/...
#
#   Computational environment captured (ie. in a virtual machine image/dockerfile/vagrantfile, etc.) in one or more research compendia   \
# 0                                                 na
# 1  https://github.com/benmarwick/1989-excavation-...
# ...
