# %%
/Volumes/Archive/notebooks/jake

# %%
# !grep -r "salinity" /Volumes/Archive/notebooks/jake
# Out:
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/search/label/MUI0X7~1:Also took salinity of the water collected as well as the treatment salinity.<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/search/label/OJX2GA~P:Also took temp, salinity and size of brooding females.</div>
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/search/label/RKAAUG~L:Also took temp, salinity and size of brooding females.</div>
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/search/label/RKAAUG~L:Also took salinity of the water collected as well as the treatment salinity.<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/2014_05_01_archive.html:Also took temp, salinity and size of brooding females.</div>
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/2014_05_01_archive.html:Also took salinity of the water collected as well as the treatment salinity.<br />
# ...

# %%
Seawater:

# %%
# !fgrep --color -r "Seawater:" /Volumes/Archive/notebooks/jake
# Out:
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/search/label/MUI0X7~1:Seawater: &nbsp; 26.5 ppt<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/search/label/RKAAUG~L:Seawater: &nbsp; 26.5 ppt<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/2014_05_01_archive.html:Seawater: &nbsp; 26.5 ppt<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/2014/05/5-28-2014-manchester-repro-check.html:Seawater: &nbsp; 26.5 ppt<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/SP644Q~P:Seawater: &nbsp; 26.5 ppt<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/SFQ3EW~Q:Seawater: &nbsp; 26.5 ppt<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/SHNWIE~5:Seawater: &nbsp; 26.5 ppt<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/S313S6~W:Seawater: &nbsp; 26.5 ppt<br />
# /Volumes/Archive/notebooks/jake/heareresearch.blogspot.com/SZCSY1~6:Seawater: &nbsp; 26.5 ppt<br />
# ...

# %%
# !fgrep --color -r "20" /Volumes/Archive/notebooks/jake
# Out:
# /Volumes/Archive/notebooks/jake/wget-log:2015-06-23 10:01:02 (8.18 MB/s) - '3.bp.blogspot.com/-iovyBZdkU_E/VWeKa5-WXhI/AAAAAAAANQs/v1lEEx7sV78/s1600/OlyPrimerCheck3%28GDF-8%29melt.JPG' saved [118718/118718]
# /Volumes/Archive/notebooks/jake/wget-log:--2015-06-23 10:01:03--  http://3.bp.blogspot.com/-iovyBZdkU_E/VWeKa5-WXhI/AAAAAAAANQs/v1lEEx7sV78/s640/OlyPrimerCheck3%2528GDF-8%2529melt.JPG
# /Volumes/Archive/notebooks/jake/wget-log:HTTP request sent, awaiting response... 200 OK
# /Volumes/Archive/notebooks/jake/wget-log:--2015-06-23 10:01:04--  http://3.bp.blogspot.com/-iovyBZdkU_E/VWeKa5-WXhI/AAAAAAAANQs/v1lEEx7sV78/s640/OlyPrimerCheck3%2528GDF-8%2529melt.JPG
# /Volumes/Archive/notebooks/jake/wget-log:HTTP request sent, awaiting response... 200 OK
# /Volumes/Archive/notebooks/jake/wget-log:2015-06-23 10:01:04 (6.98 MB/s) - '3.bp.blogspot.com/-iovyBZdkU_E/VWeKa5-WXhI/AAAAAAAANQs/v1lEEx7sV78/s640/OlyPrimerCheck3%28GDF-8%29melt.JPG' saved [99312/99312]
# ...
